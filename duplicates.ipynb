# %%
with open('C:/Users/Vaibhav/Desktop/data/mapped input/mapped_output_female_16_20.txt', 'r',encoding="utf8") as input_file:
    lines = input_file.readlines()

text = lines
result = "".join(dict.fromkeys(lines))
print(result)


with open('sorted_mapped_output_female_16_20.txt', 'w',encoding="utf8") as output_file:
        output_file.write(result)
# Out:
# राजा	rAjA
# आनी	AnI
# कोडा	kODA
# तशी	tashI
# ही	hI
# काणीच	kANIca
# दोगां	dOgAM
# मनशांची	manashAMcI
# भारतवर्ष	bhAratavarSa
# नांवाच्या	nAMvAcyA
# देशांतल्या	dEshAMtalyA
# दोन	dOna
# कोनशांनी	kOnashAMnI
# रावपी	rAvapI
# हे	hE
# मनीस	manIsa
# दोगांकय	dOgAMkaya
# जोडपी	jODapI
# समान	samAna
# सुत्र	sutra
# म्हणचे	mhaNacE
# तांची	tAMcI
# पयलींची	payalIMcI
# गरिबीची	garibIcI
# फाटभूंय	phATabhUMya
# परिस्थिती	paristhitI
# कडेन	kaDEna
# झुजतना	jhujatanA
# फुलिल्ली	phulillI
# सत्ताकांक्षा	sattAkAMkSA
# मत्ताकांक्षा	mattAkAMkSA
# राजकारणांत	rAjakAraNAMta
# अर्थकारणांत	arthakAraNAMta
# कोणाक	kONAka
# कोणा	kONA
# शय्यासोबत	shayyAsObata
# करची	karacI
# पडत	paData
# तें	tEM
# सांगपाक	sAMgapAka
# जायना	jAyanA
# अशें	ashEM
# म्हणटात	mhaNaTAta
# कारण	kAraNa
# दोनूय	dOnUya
# जोड	jODa
# आसा	AsA
# ते	tE
# जोडी	jODI
# खातीर	khAtIra
# तडजोड	taDajODa
# करचीच	karacIca
# पडटा	paDaTA
# कोडान	kODAna
# तडजोडींतल्यान	taDajODIMtalyAna
# उबारिल्ले	ubArillE
# जोडीच्या	jODIcyA
# थप्प्यो	thappyO
# पळोवन	paLOvana
# ...
